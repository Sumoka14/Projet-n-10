# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/billets.csv', sep=';')
df
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.81       104.86        104.95        4.52       2.89
# 1           True    171.46       103.36        103.66        3.77       2.99
# 2           True    172.69       104.48        103.50        4.40       2.94
# 3           True    171.36       103.91        103.94        3.62       3.01
# 4           True    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495       False    171.75       104.38        104.17        4.42       3.09
# 1496       False    172.19       104.63        104.44        5.27       3.37
# 1497       False    171.80       104.01        104.12        5.51       3.36
# 1498       False    172.06       104.28        104.06        5.17       3.46
# 1499       False    171.47       104.15        103.82        4.63       3.37
#
#       length
# 0     112.83
# 1     113.09
# ...

# %%
df.describe()
# Out:
#           diagonal  height_left  height_right   margin_low    margin_up  \
# count  1500.000000  1500.000000   1500.000000  1463.000000  1500.000000
# mean    171.958440   104.029533    103.920307     4.485967     3.151473
# std       0.305195     0.299462      0.325627     0.663813     0.231813
# min     171.040000   103.140000    102.820000     2.980000     2.270000
# 25%     171.750000   103.820000    103.710000     4.015000     2.990000
# 50%     171.960000   104.040000    103.920000     4.310000     3.140000
# 75%     172.170000   104.230000    104.150000     4.870000     3.310000
# max     173.010000   104.880000    104.950000     6.900000     3.910000
#
#            length
# count  1500.00000
# mean    112.67850
# std       0.87273
# min     109.49000
# 25%     112.03000
# 50%     112.96000
# 75%     113.34000
# max     114.44000

# %%
matrice_corr = df.drop("is_genuine", axis=1).corr().round(1)
sns.heatmap(matrice_corr, annot=True, vmin=-1, vmax=1,
            cmap=sns.color_palette("vlag", as_cmap=True))
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Traitement des valeurs manquantes

# %%
df.describe()
# Out:
#           diagonal  height_left  height_right   margin_low    margin_up  \
# count  1500.000000  1500.000000   1500.000000  1463.000000  1500.000000
# mean    171.958440   104.029533    103.920307     4.485967     3.151473
# std       0.305195     0.299462      0.325627     0.663813     0.231813
# min     171.040000   103.140000    102.820000     2.980000     2.270000
# 25%     171.750000   103.820000    103.710000     4.015000     2.990000
# 50%     171.960000   104.040000    103.920000     4.310000     3.140000
# 75%     172.170000   104.230000    104.150000     4.870000     3.310000
# max     173.010000   104.880000    104.950000     6.900000     3.910000
#
#            length
# count  1500.00000
# mean    112.67850
# std       0.87273
# min     109.49000
# 25%     112.03000
# 50%     112.96000
# 75%     113.34000
# max     114.44000

# %%
df[df.isna().any(axis=1)]
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72          True    171.94       103.89        103.45         NaN       3.25
# 99          True    171.93       104.07        104.18         NaN       3.14
# 151         True    172.07       103.80        104.38         NaN       3.02
# 197         True    171.45       103.66        103.80         NaN       3.62
# 241         True    171.83       104.14        104.06         NaN       3.02
# 251         True    171.80       103.26        102.82         NaN       2.95
# 284         True    171.92       103.83        103.76         NaN       3.23
# 334         True    171.85       103.70        103.96         NaN       3.00
# 410         True    172.56       103.72        103.51         NaN       3.12
# 413         True    172.30       103.66        103.50         NaN       3.16
# 445         True    172.34       104.42        103.22         NaN       3.01
# ...

# %% [markdown]
# ## Linéarité simple

# %%
sns.pairplot(df, hue='is_genuine', markers=['o', 's'], corner=True)

# %% [markdown]
# Comme on peut le voir aucune des variable n'a une relation normale avec la variable: "margin_low".
# <br> Une régression linéaire simple est donc impossible

# %% [markdown]
# ## Linéarité multiple

# %% [markdown]
# #### Séparation du dataframe

# %% [markdown]
# Séparation du dataframe en 2, une moitié servant à entrainer le modèle, l'autre à vérifier son efficacité.

# %%
from sklearn.model_selection import train_test_split

df_train = df.dropna(how='any')
df_train['is_genuine'] = df_train['is_genuine'].astype('category')

feat_miss = ["diagonal", "height_left", "height_right", "margin_up", "length"]


X = df_train[feat_miss]
Y = df_train["margin_low"]


# divise l'ensemble des données en un set d'entraînement et un set de test avec une répartition 70% / 30%.
# Attribuez à random_state une valeur quelconque, ce qui assure la cohérence.
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.32, random_state=657)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (994, 5)
# (469, 5)
# (994,)
# (469,)
# C:\Users\thebe\AppData\Local\Temp\ipykernel_11364\1164512834.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['is_genuine'] = df_train['is_genuine'].astype('category')

# %% [markdown]
# #### Choix des colonnes à garder

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression


lm = LinearRegression()
lm.fit(X, Y)

rfe = RFE(lm, n_features_to_select=4)             # running RFE
rfe = rfe.fit(X, Y)

list(zip(X_train, rfe.support_, rfe.ranking_))
# Out:
# [('diagonal', False, 2),
#  ('height_left', True, 1),
#  ('height_right', True, 1),
#  ('margin_up', True, 1),
#  ('length', True, 1)]

# %% [markdown]
# #### Entrainement du modèle

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
linear_model = LinearRegression()

linear_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Test du modèle

# %%
import statsmodels.formula.api as sm

# sm.OLS(Y, X).fit().summary()

# linear_model.summary()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# évaluation du modèle pour l'ensemble d'entraînement

y_train_predict = linear_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

mae = mean_absolute_error(Y_train, y_train_predict)
print("La performance du Modèle pour le set de Training")
print("------------------------------------------------")
print("l'erreur RMSE esst {}".format(rmse))
print('le score R2 est {}'.format(r2))
print("l'erreur moyenne est {}".format(mae))
print("\n")

# évaluation du modèle pour le set de tesst

y_test_predict = linear_model.predict(X_test)
# racine carrée de l'erreur quadratique moyenne du modèle
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

# score R carré du modèle
r2 = r2_score(Y_test, y_test_predict)

mae = mean_absolute_error(Y_test, y_test_predict)
print("La performance du Modèle pour le set de Test")
print("--------------------------------------------")
print("l'erreur RMSE est {}".format(rmse))
print('le score R2 score est {}'.format(r2))
print("l'erreur moyenne est {}".format(mae))
# Out:
# La performance du Modèle pour le set de Training
# ------------------------------------------------
# l'erreur RMSE esst 0.4632072239550958
# le score R2 est 0.5045294510705023
# l'erreur moyenne est 0.3642072509662987
#
#
# La performance du Modèle pour le set de Test
# --------------------------------------------
# l'erreur RMSE est 0.5151171226716798
# le score R2 score est 0.41668217813261543
# l'erreur moyenne est 0.39254998438469435

# %%
sns.regplot(x=Y_test, y=y_test_predict)
# Out:
# <AxesSubplot: xlabel='margin_low'>

# %% [markdown]
# On peut voir que cette modélisation est loin d'être idéale

# %% [markdown]
# #### Application

# %%
df.loc[df.isna().any(axis=1), 'margin_low'] = linear_model.predict(scaler.transform(df[df.isna().any(
    axis=1)][feat_miss]))

# %% [markdown]
# # Méthode des K-means

# %% [markdown]
# ## ACP

# %%
def correlation_graph(pca,
                      x_y,
                      features):

    # Extrait x et y
    x, y = x_y

    # Taille de l'image (en inches)
    fig, ax = plt.subplots(figsize=(10, 9))

    # Pour chaque composante :
    for i in range(0, pca.components_.shape[1]):

        # Les flèches
        ax.arrow(0, 0,
                 pca.components_[x, i],
                 pca.components_[y, i],
                 head_width=0.07,
                 head_length=0.07,
                 width=0.02, )

        # Les labels
        plt.text(pca.components_[x, i] + 0.05,
                 pca.components_[y, i] + 0.05,
                 features[i])

    # Affichage des lignes horizontales et verticales
    plt.plot([-1, 1], [0, 0], color='grey', ls='--')
    plt.plot([0, 0], [-1, 1], color='grey', ls='--')

    # Nom des axes, avec le pourcentage d'inertie expliqué
    plt.xlabel('F{} ({}%)'.format(
        x+1, round(100*pca.explained_variance_ratio_[x], 1)))
    plt.ylabel('F{} ({}%)'.format(
        y+1, round(100*pca.explained_variance_ratio_[y], 1)))

    plt.title("Cercle des corrélations (F{} et F{})".format(x+1, y+1))

    # Le cercle
    an = np.linspace(0, 2 * np.pi, 100)
    plt.plot(np.cos(an), np.sin(an))  # Add a unit circle for scale

    # Axes et display
    plt.axis('equal')
    plt.show(block=False)

# %%
from sklearn.preprocessing import StandardScaler

centRed = StandardScaler()

dfToScale = df.drop(columns='is_genuine')

centRed.fit(dfToScale)

dfCentreReduit = centRed.transform(dfToScale)
dfCentreReduit = pd.DataFrame(dfCentreReduit, columns=dfToScale.columns)

dfCentreReduit.describe()
# Out:
#            diagonal   height_left  height_right    margin_low     margin_up  \
# count  1.500000e+03  1.500000e+03  1.500000e+03  1.500000e+03  1.500000e+03
# mean  -7.850550e-14  4.812743e-14 -2.783433e-14 -1.250555e-15 -9.852859e-16
# std    1.000334e+00  1.000334e+00  1.000334e+00  1.000334e+00  1.000334e+00
# min   -3.010357e+00 -2.971432e+00 -3.380166e+00 -2.280129e+00 -3.803785e+00
# 25%   -6.832007e-01 -6.999333e-01 -6.460667e-01 -7.030073e-01 -6.967992e-01
# 50%    5.113189e-03  3.496326e-02 -9.420867e-04 -2.632330e-01 -4.951040e-02
# 75%    6.934271e-01  6.696467e-01  7.056229e-01  5.859863e-01  6.840835e-01
# max    3.446683e+00  2.840932e+00  3.163240e+00  3.664406e+00  3.273239e+00
#
#              length
# count  1.500000e+03
# mean   4.547474e-16
# std    1.000334e+00
# min   -3.654697e+00
# 25%   -7.433186e-01
# 50%    3.226587e-01
# 75%    7.582193e-01
# max    2.019053e+00

# %%
from sklearn.decomposition import PCA

features = dfCentreReduit.columns
names = dfCentreReduit.index

X = dfCentreReduit.values

n_components = 6
pca = PCA(n_components=n_components)
pca.fit(X)

scree = (pca.explained_variance_ratio_*100).round(2)
scree_cum = scree.cumsum().round()
x_list = range(1, n_components+1)

plt.bar(x_list, scree)
plt.plot(x_list, scree_cum, c="red", marker='o')
plt.xlabel("rang de l'axe d'inertie")
plt.ylabel("pourcentage d'inertie")
plt.title("Eboulis des valeurs propres")
plt.show(block=False)

x_y = (0, 1)
correlation_graph(pca, x_y, features)

# %%
from sklearn.cluster import KMeans

n_clusters = 2
n_components = 6

kmeans = KMeans(n_clusters=n_clusters, n_init=50)
kmeans.fit(dfCentreReduit)
labels = kmeans.labels_

pca = PCA(n_components=n_components)
pca.fit(dfCentreReduit)

X_proj = pca.transform(dfCentreReduit)
X_proj = pd.DataFrame(X_proj, columns=["PC"+str(i+1)
                      for i in range(n_components)])


fig, ax = plt.subplots(1, 1, figsize=(8, 7))
ax.scatter(X_proj.iloc[:, 0], X_proj.iloc[:, 1], c=labels, cmap="Set1")
ax.set_xlabel("F1")
ax.set_ylabel("F2")
plt.show()

# %%
df['Cluster'] = kmeans.labels_

# %% [markdown]
# ## Résultats

# %%
pd.crosstab(df.Cluster, df.is_genuine)
# Out:
# is_genuine  False  True
# Cluster
# 0              14    990
# 1             486     10

# %% [markdown]
# 98.4% de billets correctement diagnostiqués (1476/1500)
# <br> 0.9% de faux positifs (14/1500)
# <br> 0.7% de faux négatifs (10/1500)

# %% [markdown]
# ## Création de la fonction

# %%
ClusterVrai = 0
ClusterFaux = 1

# %% [markdown]
# On garde les centroïdes des 2 clusters. Pour déterminer si un billet est faux, on regarde de quel centroïde il est le plus proche.

# %%
X_proj['Cluster'] = kmeans.labels_
X_proj
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6  Cluster
# 0     1.645122  0.747316  2.395620  3.184146  0.319149 -0.018520        1
# 1    -2.019967 -2.207462 -1.002211  0.070201  0.033259 -0.475395        0
# 2    -0.970123  2.620288  1.198606 -0.916901 -0.840739  0.207846        0
# 3    -1.377178 -1.818380  0.648467  0.826014  0.804122 -0.232622        0
# 4     0.148248 -0.566089  0.856062 -1.791177  1.172277 -0.299881        0
# ...        ...       ...       ...       ...       ...       ...      ...
# 1495  1.426456 -0.269575  0.948696  0.520831 -0.246313 -1.317390        1
# 1496  3.279285  1.318062  0.617678  0.336969 -0.111351 -0.544217        1
# 1497  1.889533 -0.600266 -0.545327 -0.097769 -0.297870  0.503688        1
# 1498  1.789514  0.511437  0.028805 -0.474888  0.354632  0.525600        1
# 1499  1.042011 -1.470980  0.484907 -0.686980  0.483064 -0.234415        1
#
# [1500 rows x 7 columns]

# %%
centroids = X_proj.groupby('Cluster').mean()
centroids
# Out:
#               PC1       PC2       PC3       PC4       PC5       PC6
# Cluster
# 0       -1.020805  0.036419  0.044478  0.042355  0.068090  0.024255
# 1        2.066306 -0.073720 -0.090032 -0.085734 -0.137828 -0.049097

# %%
import math


def VraiFaux_Kmeans(df, pca=pca, centroids=centroids, ClusterVrai=ClusterVrai, ClusterFaux=ClusterFaux, features=features):

    df_Etud = df[features]

    dfCentreReduit = centRed.transform(df_Etud)
    dfCentreReduit = pd.DataFrame(dfCentreReduit, columns=df_Etud.columns)

    X_proj = pca.transform(dfCentreReduit)
    X_proj = pd.DataFrame(X_proj, columns=["PC"+str(i+1)
                                           for i in range(n_components)])

    for i in range(0, len(df)):
        billet = X_proj.iloc[i]

        distVrai = math.dist(centroids.iloc[ClusterVrai], billet)
        distFaux = math.dist(centroids.iloc[ClusterFaux], billet)

        if distVrai < distFaux:
            df.at[i, 'Prédiction_Kmean'] = True
        else:
            df.at[i, 'Prédiction_Kmean'] = False

    return df

# %% [markdown]
# # Régression logistique classique

# %%
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression

df["is_genuine"] = df["is_genuine"].astype('category')
df = df.sample(frac=1)

y = df["is_genuine"].cat.codes

x = df[features]

xt, xv = x.iloc[:750], x.iloc[750:]
yt, yv = y.iloc[:750], y.iloc[750:]

# %%
modele_logit = LogisticRegression(penalty=None, solver='newton-cg')
modele_logit.fit(xt, yt)
# Out:
# c:\Users\thebe\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_linesearch.py:456: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# c:\Users\thebe\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_linesearch.py:305: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# LogisticRegression(penalty=None, solver='newton-cg')

# %%
ypredic = modele_logit.predict(xv)

# %% [markdown]
# ## Résultats

# %%
dft = pd.DataFrame()
dft['reel'] = yv
dft['prédit'] = ypredic
pd.crosstab(dft.prédit, dft.reel)
# Out:
# reel      0    1
# prédit
# 0       258    5
# 1         2  485

# %% [markdown]
# 99.0% de billets correctement diagnostiqués (742/750)
# <br> 0.9% de faux positifs (7/750)
# <br> 0.1% de faux négatifs (1/750)

# %% [markdown]
# ## Création de la fonction

# %%
def VraiFaux_Regression_logique(df, modele_logit=modele_logit, features=features):
    x = df[features]
    df["Prédiction_Logistique"] = modele_logit.predict(x)
    return df

# %% [markdown]
# # Récapitulatif

# %%
fig, ax = plt.subplots()

# hide axes
fig.patch.set_visible(False)
ax.axis('off')
ax.axis('tight')

df = pd.DataFrame(np.random.randn(10, 4), columns=list('ABCD'))

ax.table(cellText=[[98.4,99.0], [0.8,0.9], [0.7,0.1]],
                  rowLabels=["Efficacité (%)", "Faux positifs (%)", "Faux négatifs (%)"],
                  colLabels=['Kmeans', 'Régression logique'], loc='center')

fig.tight_layout()

plt.show()

# %% [markdown]
# # Test des fonctions

# %%
df_test = pd.read_csv("Billets à tester/billets_production.csv")

# %%
VraiFaux_Kmeans(df_test)
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id  \
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5
#
#   Prédiction_Kmean
# 0            False
# 1            False
# 2            False
# 3             True
# 4             True

# %%
VraiFaux_Regression_logique(df_test)
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id  \
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5
#
#   Prédiction_Kmean  Prédiction_Logistique
# 0            False                      0
# 1            False                      0
# 2            False                      0
# 3             True                      1
# 4             True                      1
